# %% [markdown]
# # Anchor Boxes

# %% [markdown]
# The hit line:
# > Each of the box can detect only *one* object at a time. If there are overlapping objects, it will fail.

# %% [markdown]
# <img src="./images/anchor-box.png">

# %% [markdown]
# The above is the foundation.

# %% [markdown]
# # YOLO
#
# Now, we will predict 2 anchorboxes probability for **each** cell.

# %% [markdown]
# <img src="./images/yolo-1.png">

# %% [markdown]
# <img src="./images/yolo-2.png">
