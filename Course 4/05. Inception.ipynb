# %% [markdown]
# # Try them all

# %% [markdown]
# <img src="./images/inception.gif">

# %% [markdown]
# ## Now for each block, we will face the computation issue
#
# <img src="./images/problem-vanilla-conv-comp.png">

# %% [markdown]
# So, we can do this.
#
# # 👇🏻

# %% [markdown]
# <img src="./images/problem-solved-conv-comp.png">

# %% [markdown]
# # The architecture
#
# <img src="./images/inception-network.png">
