# %% [markdown]
# # Error Analysis

# %% [markdown]
# There is many information that is obvious, like how to improve and all -- but not included here. One thing that Andrew suggested is best is how to structure the table, for the analysis of the error.
#
# <img src="./images/incorrect-labels.png">

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# <img src="./images/transfer-learning.png">
